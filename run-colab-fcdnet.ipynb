# %%
from google.colab import drive
import os

# %%
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
os.chdir('gdrive/My Drive/image-segmentation')

# %%
# !python train.py -h
# Out:
# usage: train.py [-h] [--batch_size BATCH_SIZE] [--epochs EPOCHS]
#                 [--val_percent VAL_PERCENT] [--lr LR] [--device DEVICE]
#                 [--workers WORKERS] [--vis_images VIS_IMAGES]
#                 [--results RESULTS] [--model {u-net,fcd-net}] [--logs LOGS]
#                 [--images IMAGES] [--image_size IMAGE_SIZE]
#                 [--aug_scale AUG_SCALE] [--aug_angle AUG_ANGLE]
#                 [--aug_flip AUG_FLIP]
#
# Training Image Segmentation Model on Data Science Bowl 2018
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --batch_size BATCH_SIZE
#                         input batch size for training (default: 4)
#   --epochs EPOCHS       number of epochs to train (default: 100)
#   --val_percent VAL_PERCENT
#                         Validation percentage of original training set.
#                         (default 0.3)
#   --lr LR               initial learning rate (default: 0.0001)
# ...

# %%
# !python train.py --image_size 256 --model fcd-net --batch_size 8 --results results/fcdnet
# Out:
# [Data Science Bowl 2018: Nuclei detection]: =============== Parameters ===============
# [Data Science Bowl 2018: Nuclei detection]:       aug_angle : 30
# [Data Science Bowl 2018: Nuclei detection]:        aug_flip : 0.5
# [Data Science Bowl 2018: Nuclei detection]:       aug_scale : 0.05
# [Data Science Bowl 2018: Nuclei detection]:      batch_size : 8
# [Data Science Bowl 2018: Nuclei detection]:          device : cuda:0
# [Data Science Bowl 2018: Nuclei detection]:          epochs : 100
# [Data Science Bowl 2018: Nuclei detection]:      image_size : 256
# [Data Science Bowl 2018: Nuclei detection]:          images : data/data-science-bowl-2018/stage1_train
# [Data Science Bowl 2018: Nuclei detection]:            logs : logs/
# [Data Science Bowl 2018: Nuclei detection]:              lr : 0.0001
# [Data Science Bowl 2018: Nuclei detection]:           model : fcd-net
# [Data Science Bowl 2018: Nuclei detection]:         results : results/fcdnet
# ...
